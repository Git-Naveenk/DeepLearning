# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error as mse
import seaborn as sns

# %%
def sigmoid(z):
    return 1 /(1+ np.exp(-z))

# %%
def derivative_sigmoid(z):
    s=sigmoid(z)
    return s*(1-s)

# %%
X = [1, 2, 3, 4, 5]
y = []

for i in X:
    y.append(i * 2)

# %%
X = np.array(X)
y = np.array(y)

# %%
hd_w = np.random.rand(1)[0] 
hd_b = np.random.rand(1)[0]
op_w = np.random.rand(1)[0]
op_b = np.random.rand(1)[0]

# %%
losses=[]
epoch=60
learning_rate=0.03

# %%
for i in range(epoch):
    
    z1 = X * hd_w + hd_b
    a1 = sigmoid(z1)

    z2 = op_w * a1 + op_b
    y_pred = sigmoid(z2)

    
    loss = np.mean((y - y_pred) ** 2)
    print(f"Epoch {i+1}, Loss: {loss}")
    losses.append(loss)

    
    error = y_pred - y

    err_o = error * derivative_sigmoid(z2)

    hid_err = err_o * op_w
    err_hid = hid_err * derivative_sigmoid(z1)

    
    op_w = op_w - learning_rate * np.mean(err_o * a1)
    op_b = op_b - learning_rate * np.mean(err_o)

    hd_w = hd_w - learning_rate * np.mean(err_hid * X)
    hd_b = hd_b - learning_rate * np.mean(err_hid)
# Out:
# Epoch 1, Loss: 36.88695693776
# Epoch 2, Loss: 36.71528313593155
# Epoch 3, Loss: 36.550716716285265
# Epoch 4, Loss: 36.3934520160352
# Epoch 5, Loss: 36.24357381953138
# Epoch 6, Loss: 36.10107117566891
# Epoch 7, Loss: 35.9658521211141
# Epoch 8, Loss: 35.83775838953286
# Epoch 9, Loss: 35.716579411532905
# Epoch 10, Loss: 35.602065130388866
# Epoch 11, Loss: 35.493937353829054
# Epoch 12, Loss: 35.39189952130609
# Epoch 13, Loss: 35.29564488624959
# Epoch 14, Loss: 35.20486319614743
# Epoch 15, Loss: 35.119246005268224
# Epoch 16, Loss: 35.03849078194679
# Epoch 17, Loss: 34.96230398109105
# Epoch 18, Loss: 34.89040324867229
# Epoch 19, Loss: 34.82251891311227
# Epoch 20, Loss: 34.75839490225933
# Epoch 21, Loss: 34.69778920662554
# Epoch 22, Loss: 34.64047399147309
# Epoch 23, Loss: 34.586235443278895
# Epoch 24, Loss: 34.534873420673804
# Epoch 25, Loss: 34.48620096641813
# Epoch 26, Loss: 34.44004372538418
# Epoch 27, Loss: 34.3962393037788
# Epoch 28, Loss: 34.35463659678981
# Epoch 29, Loss: 34.31509510527659
# Epoch 30, Loss: 34.27748425684133
# Epoch 31, Loss: 34.24168274240958
# Epoch 32, Loss: 34.207577876137904
# Epoch 33, Loss: 34.17506498388752
# Epoch 34, Loss: 34.14404682351987
# Epoch 35, Loss: 34.11443303876377
# Epoch 36, Loss: 34.08613964727719
# Epoch 37, Loss: 34.05908856270016
# Epoch 38, Loss: 34.03320714990186
# Epoch 39, Loss: 34.00842781221398
# Epoch 40, Loss: 33.984687609170365
# Epoch 41, Loss: 33.96192790310672
# Epoch 42, Loss: 33.94009403288793
# Epoch 43, Loss: 33.91913501300268
# Epoch 44, Loss: 33.899003256280295
# Epoch 45, Loss: 33.87965431853022
# Epoch 46, Loss: 33.86104666347059
# Epoch 47, Loss: 33.84314144639212
# Epoch 48, Loss: 33.82590231509128
# Epoch 49, Loss: 33.80929522669807
# Epoch 50, Loss: 33.79328827911659
# Epoch 51, Loss: 33.77785155588738
# Epoch 52, Loss: 33.76295698336974
# Epoch 53, Loss: 33.74857819922634
# Epoch 54, Loss: 33.73469043127337
# Epoch 55, Loss: 33.72127038583485
# Epoch 56, Loss: 33.70829614481056
# Epoch 57, Loss: 33.69574707073279
# Epoch 58, Loss: 33.68360371914804
# Epoch 59, Loss: 33.67184775771618
# Epoch 60, Loss: 33.66046189147122

# %%
print("Final Prediction: ",y_pred)
# Out:
# Final Prediction:  [0.91731062 0.92783569 0.93346431 0.93628578 0.93765719]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(losses, color='forestgreen', linewidth=2)
plt.title("Model Training Loss")
plt.xlabel("Steps")
plt.ylabel("MSE Loss")
plt.show()

# %%
print("Predicted Output:")
print(np.round(y_pred, 3))
# Out:
# Predicted Output:
# [0.917 0.928 0.933 0.936 0.938]
