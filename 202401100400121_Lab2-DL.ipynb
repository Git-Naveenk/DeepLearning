# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error as mse
import seaborn as sns

# %%
def sigmoid(z):
    return 1 /(1+ np.exp(-z))

# %%
def derivative_sigmoid(z):
    s=sigmoid(z)
    return s*(1-s)

# %%
X = [1, 2, 3, 4, 5]
y = []

for i in X:
    y.append(i * 2)

# %%
X = np.array(X)
y = np.array(y)

# %%
hd_w = np.random.rand(1)[0] 
hd_b = np.random.rand(1)[0]
op_w = np.random.rand(1)[0]
op_b = np.random.rand(1)[0]

# %%
losses=[]
epoch=60
learning_rate=0.03

# %%
for i in range(epoch):
    
    z1 = X * hd_w + hd_b
    a1 = sigmoid(z1)

    z2 = op_w * a1 + op_b
    y_pred = sigmoid(z2)

    
    loss = np.mean((y - y_pred) ** 2)
    print(f"Epoch {i+1}, Loss: {loss}")
    losses.append(loss)

    
    error = y_pred - y

    err_o = error * derivative_sigmoid(z2)

    hid_err = err_o * op_w
    err_hid = hid_err * derivative_sigmoid(z1)

    
    op_w = op_w - learning_rate * np.mean(err_o * a1)
    op_b = op_b - learning_rate * np.mean(err_o)

    hd_w = hd_w - learning_rate * np.mean(err_hid * X)
    hd_b = hd_b - learning_rate * np.mean(err_hid)
# Out:
# Epoch 1, Loss: 36.45058036699304
# Epoch 2, Loss: 36.28989064381936
# Epoch 3, Loss: 36.1375887191036
# Epoch 4, Loss: 35.99357157294192
# Epoch 5, Loss: 35.85764704471704
# Epoch 6, Loss: 35.72955408599138
# Epoch 7, Loss: 35.608981109635316
# Epoch 8, Loss: 35.495581986600726
# Epoch 9, Loss: 35.388989530313566
# Epoch 10, Loss: 35.28882651663493
# Epoch 11, Loss: 35.194714422321304
# Epoch 12, Loss: 35.1062801404074
# Epoch 13, Loss: 35.02316096195392
# Epoch 14, Loss: 34.9450081140251
# Epoch 15, Loss: 34.8714891250404
# Epoch 16, Loss: 34.802289259487694
# Epoch 17, Loss: 34.73711223053416
# Epoch 18, Loss: 34.675680365357586
# Epoch 19, Loss: 34.61773436645827
# Epoch 20, Loss: 34.563032784063445
# Epoch 21, Loss: 34.511351290489515
# Epoch 22, Loss: 34.46248182698689
# Epoch 23, Loss: 34.41623167688379
# Epoch 24, Loss: 34.37242250535776
# Epoch 25, Loss: 34.330889395439314
# Epoch 26, Loss: 34.29147990143904
# Epoch 27, Loss: 34.25405313447471
# Epoch 28, Loss: 34.21847888979134
# Epoch 29, Loss: 34.1846368218077
# Epoch 30, Loss: 34.15241567002478
# Epoch 31, Loss: 34.121712536887124
# Epoch 32, Loss: 34.09243221722252
# Epoch 33, Loss: 34.064486577865786
# Epoch 34, Loss: 34.03779398538843
# Epoch 35, Loss: 34.01227877942516
# Epoch 36, Loss: 33.98787078884369
# Epoch 37, Loss: 33.96450488789656
# Epoch 38, Loss: 33.94212058948385
# Epoch 39, Loss: 33.92066167271352
# Epoch 40, Loss: 33.90007584205121
# Epoch 41, Loss: 33.88031441548513
# Epoch 42, Loss: 33.86133203928399
# Epoch 43, Loss: 33.84308642708574
# Epoch 44, Loss: 33.82553812121828
# Epoch 45, Loss: 33.80865027431291
# Epoch 46, Loss: 33.79238844942717
# Epoch 47, Loss: 33.776720437040716
# Epoch 48, Loss: 33.761616087427896
# Epoch 49, Loss: 33.74704715704045
# Epoch 50, Loss: 33.732987167654315
# Epoch 51, Loss: 33.71941127714697
# Epoch 52, Loss: 33.70629616087307
# Epoch 53, Loss: 33.693619902701094
# Epoch 54, Loss: 33.68136189485873
# Epoch 55, Loss: 33.669502745813745
# Epoch 56, Loss: 33.658024195487236
# Epoch 57, Loss: 33.64690903716195
# Epoch 58, Loss: 33.63614104550589
# Epoch 59, Loss: 33.625704910185775
# Epoch 60, Loss: 33.615586174592

# %%
print("Final Prediction: ",y_pred)
# Out:
# Final Prediction:  [0.92569283 0.93472477 0.93859336 0.94017507 0.94081033]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(losses, color='forestgreen', linewidth=2)
plt.title("Model Training Loss")
plt.xlabel("Steps")
plt.ylabel("MSE Loss")
plt.show()

# %%
print("Predicted Output:")
print(np.round(y_pred, 3))
# Out:
# Predicted Output:
# [0.926 0.935 0.939 0.94  0.941]
